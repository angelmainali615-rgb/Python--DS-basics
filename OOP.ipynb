# %%
#### Session Objectives:
*   Understand the motivation behind Object-Oriented Programming.
*   Learn the core concepts: Classes, Objects, Attributes, and Methods.
*   Learn how to define a simple class in Python.
*   Understand the purpose and usage of the `__init__` constructor method.
*   Learn how to create instances (objects) of a class.
*   Learn how to access object attributes and call object methods.

# %%
OOPs:
Analogy: Building a house
    A class is like a blueprint — it defines the structure and features (walls, doors, rooms).
    An object is a real house built from that blueprint — each with its own color, size, and number of rooms.

OOP helps by:
    Organizing code around real-world concepts
    Making it easier to reuse, extend, and maintain
    Allowing creation of multiple unique instances from a single design

# %%
### Core OOP Concepts

1. Class
    A blueprint for creating objects.
    Like a house plan that defines what every house should have.
    class House:


2. Object (Instance)
    A concrete version of a class with real values.
    A specific house built from the blueprint.
    my_house = House()


3. Attribute
    Data stored in an object.
    Features of a house like color, size, address.
    my_house.color = "blue"


4. Method
    A function inside a class that defines behavior.
    Actions like open_door(), turn_on_lights().
    my_house.open_door()

# %%
class Dog:
    pass

# %%
#creating class objects 
dog1=Dog()
dog2=Dog()

# %%
print(type(dog1))
print(type(dog2))

print(dog1)
print(dog2)
print(dog1 == dog2)
# Out:
# <class '__main__.Dog'>
# <class '__main__.Dog'>
# <__main__.Dog object at 0x0000028F227F7A10>
# <__main__.Dog object at 0x0000028F22665E50>
# False

# %%
### the __init__ constructor

# %%
class Dog:
    def __init__(self,name,breed,age):
        self.name=name
        self.breed=breed
        self.age=age
        print(f"A new Dog object named {self.name} was created!")

# %%
#Creating objects with attributes
dog1 = Dog("Buddy", "Golden Retriever", 3)
dog2 = Dog("Lucy", "German Shepherd", 5)
# Out:
# A new Dog object named Buddy was created!
# A new Dog object named Lucy was created!

# %%
dog1.name
# Out:
# 'Buddy'

# %%
dog2.age
# Out:
# 5

# %%
# Accessing Attributes
# We use the dot (`.`)

# `object_name.attribute_name`


print(f"Dog 1's Name: {dog1.name}")
print(f"Dog 1's Breed: {dog1.breed}")
print(f"Dog 1's Age: {dog1.age}")


print(f"\nDog 2's Name: {dog2.name}")
print(f"Dog 2's Breed: {dog2.breed}")
print(f"Dog 2's Age: {dog2.age}")

print(f"\nIs dog1's name the same as dog2's name? {dog1.name == dog2.name}")
# Out:
# Dog 1's Name: Buddy
# Dog 1's Breed: Golden Retriever
# Dog 1's Age: 3
#
# Dog 2's Name: Lucy
# Dog 2's Breed: German Shepherd
# Dog 2's Age: 5
#
# Is dog1's name the same as dog2's name? False

# %%
### Defining Methods

# Methods are functions defined inside a class that define the object's behavior. They also take `self` as the first parameter,
# allowing them to access and modify the object's attributes.


class Dog:
    def __init__(self, name, breed, age):
        self.name = name
        self.breed = breed
        self.age = age
        print(f"A new Dog object named {self.name} was created!")


    def bark(self):
        print(f"{self.name} says: Woof! Woof!")

    def describe(self):
        print(f"This is {self.name}, a {self.age}-year-old {self.breed}.")

    def have_birthday(self):
        self.age += 1
        print(f"Happy Birthday, {self.name}! You are now {self.age} years old.")

# %%
dog3=Dog("Samir","bulldog",4)
dog4=Dog("kriti","huskey",5)
# Out:
# A new Dog object named Samir was created!
# A new Dog object named kriti was created!

# %%
dog3.bark()
# Out:
# Samir says: Woof! Woof!

# %%
dog3.describe()
# Out:
# This is Samir, a 4-year-old bulldog.

# %%
dog3.have_birthday()
# Out:
# Happy Birthday, Samir! You are now 5 years old.

# %%
class Dog:
    def __init__(self, name, breed, age):
        self.name = name
        self.breed = breed
        self.age = age
        print(f"A new Dog object named {self.name} was created!")


    def bark(self):
        print(f"{self.name} says: Woof! Woof!")

    def describe(self,location):
        print(f"This is {self.name}, a {self.age}-year-old {self.breed}.Normally found in {location}")

    def have_birthday(self):
        self.age += 1
        print(f"Happy Birthday, {self.name}! You are now {self.age} years old.")

# %%
dog4=Dog("Shristita","bulldog",4)
# Out:
# A new Dog object named Shristita was created!

# %%
dog4.describe("Bhaktapur")
# Out:
# This is Shristita, a 4-year-old bulldog.Normally found in Bhaktapur

# %%
class student:
    def __init__(self,name,age):
        self.name=name
        self.age=age
        print(f"A new student object named {self.name} was created!")
    def introduce(self, College):
        print(f"Hi! my name is {self.name} and Iam {self.age} years old. I study in {College}")

# %%
student1=student("Angel",20)
student2=student("Samir",19)
# Out:
# A new student object named Angel was created!
# A new student object named Samir was created!

# %%
student1.introduce("Patan Multiple Campus")
student2.introduce("Blue Bird College")
# Out:
# Hi! my name is Angel and Iam 20 years old. I study in Patan Multiple Campus
# Hi! my name is Samir and Iam 19 years old. I study in Blue Bird College

# %% [markdown]
# # __Inheritance__

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        print(f"Person object created: {self.name}")

    def introduce(self):
        print(f"Hi, my name is {self.name} and I am {self.age} years old.")

    def walk(self):
        print(f"{self.name} is walking.")

# %%
#create a person object
p1=Person("Angel",20)
p1.introduce()
p1.walk()
# Out:
# Person object created: Angel
# Hi, my name is Angel and I am 20 years old.
# Angel is walking.

# %%
#syntax: class ClassName(ParentClassName)

class Student(Person):
    pass
s1=Student("Bob",19)
print(f"Student's Name:{s1.name}")
s1.introduce()
s1.walk()
# Out:
# Person object created: Bob
# Student's Name:Bob
# Hi, my name is Bob and I am 19 years old.
# Bob is walking.

# %%
class Student(Person):
    def __init__(self,name,age,student_id,course):
        super().__init__(name,age)
        self.student_id=student_id
        self.course=course
    def intro(self):
        print(f"Hello! Iam {self.name}, my student id {self.student_id} and my course is {self.course}")
    def introduce(self):
        print(f"Good Morning! Iam {self.name} and I am {self.age} years old")
student1=Student("Angel",19,"ID40","Bsc CSIT")
# Out:
# Person object created: Angel

# %%
student1.intro()
# Out:
# Hello! Iam Angel, my student id ID40 and my course is Bsc CSIT

# %%
student1.introduce()
# Out:
# Good Morning! Iam Angel and I am 19 years old

# %%
s1.introduce()
# Out:
# Hi, my name is Bob and I am 19 years old.
