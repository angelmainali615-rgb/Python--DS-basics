# %% [markdown]
# #Angel

# %% [markdown]
# # Title
# ## headings
# ### sub headings
# #### smaller subheading

# %% [markdown]
# **Angel**

# %% [markdown]
# *Angel*

# %%
counter=10

# %%
counter=counter+1

# %%
counter
# Out:
# 11

# %%
counter=20

# %%
counter= counter*20

# %%
counter
# Out:
# 400

# %%
counter=40

# %%
counter+=4

# %%
counter
# Out:
# 44

# %%
5 + False
# Out:
# 5

# %%
3 + True
# Out:
# 4

# %%
a = None

# %%
type(a)
# Out:
# NoneType

# %%
angel='''"angel, can you give me a coffee?" 
Dad:No sun."'''

# %%
angel
# Out:
# '"angel, can you give me a coffee?" \nDad:No sun."'

# %%
print(angel)
# Out:
# "angel, can you give me a coffee?"
# Dad:No sun."

# %%
#length of string
len(angel)
# Out:
# 48

# %%
multiline_string="""a
b"""

# %%
multiline_string
# Out:
# 'a\nb'

# %%
len(multiline_string)
# Out:
# 3

# %%
list(multiline_string)
# Out:
# ['a', '\n', 'b']

# %% [markdown]
# __string also support several list operations
# you can acess individual characters within a string using the [] indexing notation. Note the character indices go from 0 to n-1, n is the length of string.__

# %%
today="saturday"

# %%
today[0]
# Out:
# 's'

# %%
today[1]
# Out:
# 'a'

# %% [markdown]
# __You can also access a part of a string using by providing a start:end range istead of a single index in []__

# %%
today[5:8]
# Out:
# 'day'

# %% [markdown]
# __You can also check whether a string contains a some text using the in operator__

# %%
'day' in today
# Out:
# True

# %%
'sun' in today
# Out:
# False

# %% [markdown]
# __Two or more string can be  joined or concatenated using the + operator. Be careful while concatenating strings, sometimes you may need to add a space character " " between words.__

# %%
str1="Angel Mainali"

# %%
str2="Hello"

# %%
str2+" "+str1
# Out:
# 'Hello Angel Mainali'

# %%
print(str2+" "+str1)
# Out:
# Hello Angel Mainali

# %% [markdown]
# Strings in python have many built-in methoda that are used to manipulate them. Let's try out some common string methods.

# %% [markdown]
#    __Methods:__ Methods are functions asssociated with data types and are accessed using . notation. e.g. variable name.method() or "a string".method(). Methods are a powerful technique for associating common operations with values of specific data types.

# %% [markdown]
# The __lower()__,__upper()__ and __capitalize()__ methods are used to change the case of characters'

# %%
name="ANGEL"

# %%
name.lower()
# Out:
# 'angel'

# %%
subject="English"

# %%
subject.upper()
# Out:
# 'ENGLISH'

# %%
var="angel"

# %%
var.capitalize() #changes first character to uppercase
# Out:
# 'Angel'

# %% [markdown]
# The __.replace__ method replaces the part of the string with another string. It takes the portion to be replaced and the replacement text as inputs or arguments.

# %%
day="sunday"

# %%
next_day=day.replace("sun", "mon")

# %%
print(next_day)
# Out:
# monday

# %% [markdown]
# Note that _replace_ returns a new string, and the original string is not modified.

# %%
day
# Out:
# 'sunday'

# %% [markdown]
# The __.split__ method splits a string into a list of strings at every occurence of provided character(s).

# %%
"sun,mon,tue,wed,thu,Fri,sat".split(",")
# Out:
# ['sun', 'mon', 'tue', 'wed', 'thu', 'Fri', 'sat']

# %% [markdown]
# The __.strip__ method removes whitespace characters from the beginning and end of the string.

# %%
line="       My name is     angel mainali       "

# %%
line_stripped=line.strip()

# %%
print(line_stripped)
# Out:
# My name is     angel mainali

# %% [markdown]
# The __.format__ method combines values of other data types, e.g., integers,floats,booleans,lists, etc. with strings. You can use __format__ to construct output messages for display.

# %%
cost_of_bag= 1.25
profit=.3
Total_bags=400
#Template for output message
output_template= """If a grocery store sells bags at {} per bag with a profit margin of {} then the total profit is {}."""
print(output_template)
# Out:
# If a grocery store sells bags at {} per bag with a profit margin of {} then the total profit is {}.

# %%
#inserting values into the string
total_profit= cost_of_bag*profit*Total_bags
output=output_template.format(cost_of_bag,profit*100,total_profit)
print(output)
# Out:
# If a grocery store sells bags at 1.25 per bag with a profit margin of 30.0 then the total profit is 150.0.

# %% [markdown]
# Notice how the placeholders {} in the output_template string are replaced with the arguments provided to the __.format__ method
