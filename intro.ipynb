# %%
print("Name")
# Out:
# Name

# %%
print("Angel Mainali")
# Out:
# Angel Mainali

# %%
print("25")
print("35")
print(25+35)
# Out:
# 25
# 35
# 60

# %%
### About jupyter notebook

# %%
###comments
# single line
''' multi-line comment '''
"""

multi-line   comment """
# Out:
# '\n\nmulti-line   comment '

# %%
string
integer
float
boolean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 string
#       2 integer
#       3 float
#
# NameError: name 'string' is not defined

# %%
y="5"
type(y)
# Out:
# str

# %%
x=6
type(x)
# Out:
# int

# %%
z= x + int(y)
print(z)
# Out:
# 11

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
print(type(y))
# Out:
# <class 'str'>

# %%
b=str(x)

# %%
b+y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 b+y
#
# NameError: name 'y' is not defined

# %%
age=int(input ("age:"))
# Out:
# age: 25

# %%
name=input("enter the name :")
# Out:
# enter the name : Angel

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
price=float(input("enter price:"))
# Out:
# enter price: 25.99

# %%
type(price)
# Out:
# float

# %%
name=input("name:")
age=int (input("age:"))
# Out:
# name: Angel Mainali
# age: 20

# %%
print("my name is:",name,"my age is:",age)
# Out:
# my name is: Angel Mainali my age is: 20

# %%
#fstring
print(f" My name is {name} and age is {age}")
# Out:
#  My name is Angel Mainali and age is 20

# %%
#format
print("my name is  {} {}".format(name,age))
# Out:
# my name is  Angel Mainali 20

# %%
a="50"
z=1j
b=3.5
is_student=True
# Out:
# bool

# %%
print(type(a))
print(type(z))
print(type(b))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'complex'>
# <class 'float'>
# <class 'bool'>

# %%
b="Namaste"
a="Hello "
c=a+b
print(c)
# Out:
# Hello Namaste

# %%
a="55"
b="3"
c=a+b
print(c)
# Out:
# 553

# %%
num1=int(input("enter the first number"))
num2=int(input("enter the second number"))
# Out:
# enter the first number 25
# enter the second number 35

# %%
sum=num1+num2
print(sum)
# Out:
# 60

# %%
print(num1)
print(num2)
# Out:
# 25
# 35

# %%
type(num1)
# Out:
# int

# %%
type(num2)
# Out:
# int

# %%
#assign multiple values
a,b=3,4
a=b
temp=3

b=temp
#a,b = b,a(can swap values )

# %%
print(a)
# Out:
# 4

# %%
print(b)
# Out:
# 3

# %%
a,b=4,5
a,b=b,a

# %%
print(a)
# Out:
# 5

# %%
print(b)
# Out:
# 4

# %%
x=y=z="bird"
print(f" value of {x}, value of {y},value of {z}")
# Out:
#  value of bird, value of bird,value of bird

# %%
result=5>9

# %%
print(result)
# Out:
# False

# %%
type(result)
# Out:
# bool
