# %% [markdown]
# **Today's Topics:**
#
# 1.  **Functions:**
#     *   What they are and why we use them.
#     *   Defining your own functions (`def`).
#     *   Passing information *into* functions (Parameters and Arguments).
#     *   Getting results *back* from functions (`return`).
# 2.  **Variable Scope:**
#     *   Where variables exist (Local vs. Global).
#     *   How long variables exist (Lifetime).
# 3.  **Lambda Functions:** A shortcut for creating simple, one-line functions.
#
# 4.  **Operations on String:** Operation that can be done with string

# %% [markdown]
# # Benefits shown:
# - Reusability: The greeting logic and separator are written once in `greet_person`.
# - Readability: `greet_person("Alice")` clearly states the intent.

# %% [markdown]
# **Syntax for Defining:**
#
# def function_name():  # Use 'def', choose a name, add parentheses (), and a colon :
#     # Indented block of code (the function's body)
#     # This code runs ONLY when the function is called
#     print("Hello from inside the function!")
#     # More code can go here...

# %%
def greet_person(var1):
   print(f"Hello, {var1}")

greet_person("Angel")
# Out:
# Hello, Angel

# %%
def Addition(var1,var2):
    print(f"Addition(var1,var2):{var1+var2}")
Addition(4,5)
# Out:
# Addition(var1,var2):9

# %%
def greet_person(name,surname):
    print(f"Hello, {name} {surname}!")
greet_person("Angel","Mainali")
# Out:
# Hello, Angel Mainali!

# %%
# 1. Define a simple function
def greet_user():
   
    print("Hello there, user!")
    print("Welcome to the world of functions.")

# --- Code outside the function ---
print("Program starting...")
# Out:
# Program starting...

# %%
greet_user()
# Out:
# Hello there, user!
# Welcome to the world of functions.

# %%
def add(a,b):
   result=a+b
    
   return result

# %%
add(4,5)
# Out:
# 9

# %%
def operations(a,b):
    result=a+b
    result1=a-b
    result2=a*b
    result3=a/b

    return result,result1,result2,result3

# %%
add_result,sub_result,mul_result,div_result=operations(10,7)
print(add_result)
print(sub_result)
print(mul_result)
print(div_result)
# Out:
# 17
# 3
# 70
# 1.4285714285714286

# %% [raw]
# def add_numbers():
#
#
#     result = x + y +c
#     print(f"The sum of {x} and {y} is: {result}")
#     return x
#
# add_numbers(2, 4,6)
# #this is wrong since the function has no parameters but we have given parameters

# %%
#fruitful functions
## functions that perform a specific task and return a value or result after their execution

# %%
def add(a,b):
   
    return a + b
   
x = int(input("Enter the first number:"))
y = int(input("Enter the second number:"))

result = add(x,y)
print(f"Result of {x} and {y}:  {result}")
# Out:
# Enter the first number: 20
# Enter the second number: 30
# Result of 20 and 30:  50

# %%
#*args and **kargs 
# Use *args to pass multiple positional arguments 

def show_args(*args):
    lists=""
    for item in args:
        print(item)
        lists+=item
    return lists

value=show_args("1","2")
print(value)
# Out:
# 1
# 2
# 12

# %%
def show_args(*args):
    global lists 
    lists=0
    for item in args:
        print(item)
        lists+=int(item)
    return lists

value=show_args("12","13")
print(value)
print(lists)
# Out:
# 12
# 13
# 25
# 25

# %%
sum = 0
def addition(*args):
    for item in args:
        global sum
        sum = sum + item
    return sum

addition(1,2,4,22,44,55,55)
# Out:
# 183

# %%
def sub(*args):
    global lists
    lists=0
    for item in (args):
        print(item)
        lists-=int(item)
    return lists

value=sub("2","3","4","5")
print(value)
# Out:
# 2
# 3
# 4
# 5
# -14

# %%
def sub(var1,var2):
    return var1-var2;

a=int(input("enter first number:"))
b=int(input("enter second number:"))

result=sub(a,b)

print(f"subtraction(a-b):{result}")
# Out:
# enter first number: 40
# enter second number: 20
# subtraction(a-b):20

# %%
def str_operations(var1,var2):
    result2=var1+var2
    result1=len(var1+var2)
    return result2,result1

str1=input("enter first string:")
str2=input("enter second string:")

concat,length=str_operations(str1,str2)
print(concat)
print(length)
# Out:
# enter first string: Angel
# enter second string: Mainali
# AngelMainali
# 12

# %%
# Use **kwargs to pass multiple keyword arguments.
def show_kwargs(**kwargs):
    for key, value in kwargs.items():
        print(f"{key} = {value}")

show_kwargs(name="Alice", age=22, surname= "Doe", grade="10")
# Out:
# name = Alice
# age = 22
# surname = Doe
# grade = 10

# %%
def show_kwargs(*args,**kwargs):
    for key, value in kwargs.items():
        print(f"{key} = {value}")

    for item in args:
        print(item)

show_kwargs(1,2,3,4,5,name="Alice", age=22, surname= "Doe", grade="10")
# Out:
# name = Alice
# age = 22
# surname = Doe
# grade = 10
# 1
# 2
# 3
# 4
# 5

# %%
#global
x = "Namaste"

def function():
    print(" " + x)
    t = "Hello"
    print(" " + t)
    

function()
print(x)
print(t)
# Out:
#  Namaste
#  Hello
# Namaste
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 12
#      10 function()
#      11 print(x)
# ---> 12 print(t)
#
# NameError: name 't' is not defined

# %%
#global
x = "Namaste"

def function():
    print(" " + x)
    t = "Hello"
    print(" " + t)
    print(t)
   

function()
print(x)
# Out:
#  Namaste
#  Hello
# Hello
# Namaste

# %%
x = "Namaste"

def greet():
  x = "Hello"
  print("English says " + x)

greet()

print("Nepali says " + x)
# Out:
# English says Hello
# Nepali says Namaste

# %% [markdown]
# ## 4. Lambda Functions (Anonymous Functions)
#
# Python allows you to create small, unnamed functions using the `lambda` keyword. These are useful for short operations where defining a full function with `def` feels overly verbose.
#
# **Syntax:**
# `lambda arguments: expression`
#
# *   `lambda`: Keyword.
# *   `arguments`: Comma-separated arguments
# *   `expression`: A single expression whose result is implicitly returned. Lambda functions cannot contain multiple statements or complex logic.
#
# They are often used in places where a function object is required, like arguments to `sorted()`, `map()`, `filter()`.

# %%
double= lambda x,y:x*y
print(double(8,4))
# # equivalent to function 
#def double (x,y)
#   return x*y
# Out:
# 32

# %%
type(double)
# Out:
# function

# %%
add= lambda x,y:x+y
result=add(5,4)
print(f" addition:{result}")
# Out:
#  addition:9

# %%
pairs=[(8,3,10),(2,4,5),(1,7,8)]
sorted_pairs=sorted(pairs, key=lambda x: x[2])
print(f"the sorted pairs are:{sorted_pairs}")
# Out:
# the sorted pairs are:[(2, 4, 5), (1, 7, 8), (8, 3, 10)]

# %%
zero_index=sorted(pairs, key=lambda x: x[0])

# %%
print(zero_index)
# Out:
# [(1, 7, 8), (2, 4, 5), (8, 3, 10)]

# %%
first_index=sorted(pairs, key=lambda x: x[1])

# %%
print(first_index)
# Out:
# [(8, 3, 10), (2, 4, 5), (1, 7, 8)]

# %%
pairs[0]
# Out:
# (8, 3, 10)

# %%
pairs[1]
# Out:
# (2, 4, 5)

# %%
pairs[0][2]
# Out:
# 10

# %%
pair=[(8,(3,6))]

# %%
pair[0]
# Out:
# (8, (3, 6))

# %%
pair[0][1]
# Out:
# (3, 6)

# %%
pair[0][1][0]
# Out:
# 3

# %%
pairs = [(1, 'one'), (3, 'three'), (2, 'two')]
sorted_pairs = sorted(pairs, key=lambda x: x[0])  
print(sorted_pairs)
# Out:
# [(1, 'one'), (2, 'two'), (3, 'three')]

# %%
pairs = [(1, 'one'), (3, 'three'), (2, 'two')]
sorted_pairs = sorted(pairs, key=lambda x: x[1])  
print(sorted_pairs)
# Out:
# [(1, 'one'), (3, 'three'), (2, 'two')]

# %%
pairs[1]
# Out:
# (3, 'three')

# %%
#map
numbers = [1, 2, 3, 4]
squared = list(map(lambda x: x * 2, numbers))
print(squared)
# Out:
# [2, 4, 6, 8]

# %%
nums = [1, 2, 3, 4, 5, 6]
evens = list(filter(lambda x: x % 2 == 0, nums))
print(evens)
# Out:
# [2, 4, 6]
